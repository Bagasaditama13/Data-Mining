# %%
import numpy as np

# %%
X = np.array([5, 4, 6, 5, 5, 5, 6, 6, 2, 7, 7])
y = np.array([85, 103, 70, 82, 89, 98, 66, 95, 169, 70, 48])

# %%
X_mean = np.mean(X)
y_mean = np.mean(y)

# %%
b = np.sum((X - X_mean) * (y - y_mean)) / np.sum((X - X_mean) ** 2)

# %%
a = y_mean - b * X_mean

# %%
a, b
# Out:
# (195.46846846846844, -20.261261261261257)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))

# %%
plt.scatter(X, y, color='blue', label='Data Asli', alpha=0.7)

# %%
plt.plot(X_line, y_line, color='red', label='Garis Regresi')

# %%
plt.title('Regresi Linier: Usia Mobil vs Harga Mobil', fontsize=14)
plt.xlabel('Usia Mobil (tahun)', fontsize=12)
plt.ylabel('Harga Mobil ($100)', fontsize=12)
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
